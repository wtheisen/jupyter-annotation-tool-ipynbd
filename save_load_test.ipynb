# %%
print('SMILE')


print('KITTY')
# Out:
# SILE
# KITTY

# %% [markdown]
# ### Introduction to DFS:
#
# DFS is a ________ algorithm using a __________________
# If we had the following tree, what order would we visit our nodes in?
#
# ```
#
#
#
#
#
#
#
#
#
#
#
# ```
#
# This is different from BFS where we use a ________________

# %%
def dfs(g):
# Out:
#   Cell In[1], line 1
#     def dfs(g):
#                ^
# _IncompleteInputError: incomplete input
